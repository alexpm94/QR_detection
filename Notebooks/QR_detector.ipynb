# %%
from google.colab import drive

drive.mount('/content/drive', force_remount=True)

# %cd /content/drive/MyDrive
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive

# %%
# !apt install --allow-change-held-packages libcudnn8=8.1.0.77-1+cuda11.2
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libcudnn8 is already the newest version (8.1.0.77-1+cuda11.2).
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.

# %%
# %cd /content/drive/MyDrive/tensorflow/
# !git clone https://github.com/tensorflow/models.git

# %%
# %cd /content/drive/MyDrive/tensorflow/models/research
# !protoc object_detection/protos/*.proto --python_out=.
# Out:
# /content/drive/MyDrive/Zygo/models/research

# %%
# %cd /content/drive/MyDrive/tensorflow/models/research
# !cp object_detection/packages/tf2/setup.py . 
# !python -m pip install .
# Out:
# /content/drive/MyDrive/Zygo/models/research
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/drive/MyDrive/Zygo/models/research
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=21919429 sha256=4a0e86e1847d1547f222705f7024c39ad3494b2a05732eb1f42041a890a6485a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-v5gm313q/wheels/3f/31/7c/82a9552ba7a381925444025454087fd9031c624b66db09ae84
# Successfully built object-detection
# ...
#   Attempting uninstall: object-detection
#     Found existing installation: object-detection 0.1
#     Uninstalling object-detection-0.1:
#       Successfully uninstalled object-detection-0.1
# ...

# %%
import glob
import os

# %%
# %cd /content/drive/MyDrive/QR/

# !wget https://universe.roboflow.com/ds/LF0DZgRQI6?key=Hf4B4bqqMl
# Out:
# /content/drive/MyDrive/QR
# --2023-01-30 05:42:35--  https://universe.roboflow.com/ds/LF0DZgRQI6?key=Hf4B4bqqMl
# Resolving universe.roboflow.com (universe.roboflow.com)... 151.101.1.195, 151.101.65.195
# Connecting to universe.roboflow.com (universe.roboflow.com)|151.101.1.195|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://storage.googleapis.com/roboflow-platform-exports/4F111X4OAdNVJXzzPwya0t9a4Jl2/yZv9CIZJ2Bo6LQ48u9nX/2/voc.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=481589474394-compute%40developer.gserviceaccount.com%2F20230130%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230130T054235Z&X-Goog-Expires=901&X-Goog-SignedHeaders=host&X-Goog-Signature=... [following]
# ...

# %%
# !unzip LF0DZgRQI6?key=Hf4B4bqqMl
# Out:
# Archive:  LF0DZgRQI6?key=Hf4B4bqqMl
# replace README.dataset.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#  extracting: README.dataset.txt
#  extracting: README.roboflow.txt
#  extracting: test/blurredimage002_jpg.rf.7ec6eee0a60770701b0022064f3a8f1a.jpg
#  extracting: test/blurredimage002_jpg.rf.7ec6eee0a60770701b0022064f3a8f1a.xml
#  extracting: test/blurredimage008_jpg.rf.2962fb6f1d6c9422dac9d96f25e7674b.jpg
#  extracting: test/blurredimage008_jpg.rf.2962fb6f1d6c9422dac9d96f25e7674b.xml
#  extracting: test/blurredimage027_jpg.rf.e94fcc2b67337004cfb93e259d74a53d.jpg
#  extracting: test/blurredimage027_jpg.rf.e94fcc2b67337004cfb93e259d74a53d.xml
#  extracting: test/blurredimage042_jpg.rf.ee99457751d45c863cb6222512c2d94b.jpg
#  extracting: test/blurredimage042_jpg.rf.ee99457751d45c863cb6222512c2d94b.xml
#  extracting: test/bright_spotsimage007_jpg.rf.435f8e3a6b2ff9da4d37dafc5de4ffbb.jpg
#  extracting: test/bright_spotsimage007_jpg.rf.435f8e3a6b2ff9da4d37dafc5de4ffbb.xml
# ...

# %%
import glob
import pandas as pd
import xml.etree.ElementTree as ET

# %%
def xml_to_csv(path):
    xml_list = []
    for xml_file in glob.glob(path + '/*.xml'):
        tree = ET.parse(xml_file)
        root = tree.getroot()
        for member in root.findall('object'):
            value = (root.find('filename').text,
                     int(root.find('size')[0].text),
                     int(root.find('size')[1].text),
                     member[0].text,
                     int(member[5][0].text),
                     int(member[5][1].text),
                     int(member[5][2].text),
                     int(member[5][3].text)
                     )
            xml_list.append(value)
    column_name = ['filename', 'width', 'height', 'class', 'xmin', 'xmax', 'ymin', 'ymax']
    xml_df = pd.DataFrame(xml_list, columns=column_name)
    
    return xml_df

# %%
# Read test data and save csv
xml_path = "test/"
df = xml_to_csv(xml_path)
df.to_csv("/content/drive/MyDrive/QR/test_labels.csv", index=None)
print("SUCCESSFULLY SAVED!")
# Out:
# SUCCESSFULLY SAVED!

# %%
# Read train data and save csv
xml_path = "train/"
df = xml_to_csv(xml_path)
df.to_csv("/content/drive/MyDrive/QR/train_labels.csv", index=None)
print("SUCCESSFULLY SAVED!")
# Out:
# SUCCESSFULLY SAVED!

# %%
df = pd.read_csv("/content/drive/MyDrive/QR/train_labels.csv")
images_train_path = "/content/drive/MyDrive/QR/train/"
df.filename = images_train_path+df.filename
df.to_csv("/content/drive/MyDrive/QR/train_labels.csv", index=None)

# %%
df = pd.read_csv("/content/drive/MyDrive/QR/test_labels.csv")
images_test_path = "/content/drive/MyDrive/QR/test/"
df.filename = images_test_path+df.filename
df.to_csv("/content/drive/MyDrive/QR/test_labels.csv", index=None)

# %%
# %cd /content/drive/MyDrive/QR/
# For the train dataset
# !python generate_tfrecord.py --csv_input=train_labels.csv  --output_path=train_qr.record
# For the test dataset
# !python generate_tfrecord.py --csv_input=test_labels.csv  --output_path=test_qr.record
# Out:
# /content/drive/MyDrive/QR
# 2023-01-30 05:56:13.980878: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-30 05:56:14.861504: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-30 05:56:14.861600: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...

# %%
# %cd /content/drive/MyDrive/QR
# !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Unzip
# !tar -xzvf ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Out:
# /content/drive/MyDrive/QR
# --2023-01-30 05:56:50--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.250.4.128, 2404:6800:4003:c02::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.250.4.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20515344 (20M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’
#
# ssd_mobilenet_v2_fp 100%[===================>]  19.56M  79.3MB/s    in 0.2s
#
# 2023-01-30 05:56:50 (79.3 MB/s) - ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’ saved [20515344/20515344]
#
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ...

# %%
# %cd /content/drive/MyDrive/Zygo/models/research/object_detection/
#train 
# !python model_main_tf2.py \
--pipeline_config_path=/content/drive/MyDrive/QR/pipeline.config \
--model_dir=/content/drive/MyDrive/QR/training --alsologtostderr
# Out:
# /content/drive/MyDrive/Zygo/models/research/object_detection
# 2023-01-30 06:04:18.332032: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-30 06:04:19.266410: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-30 06:04:19.266509: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...

# %%
# %cd /content/drive/MyDrive/models/research/object_detection
# !python exporter_main_v2.py \
--trained_checkpoint_dir=/content/drive/MyDrive/QR/training \
--pipeline_config_path=/content/drive/MyDrive/QR/pipeline.config \
--output_directory /content/drive/MyDrive/QR/inference
# Out:
# /content/drive/MyDrive/models/research/object_detection
# 2023-01-30 06:26:12.120972: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-30 06:26:13.079314: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-30 06:26:13.079423: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...

# %%
import tensorflow as tf
detection_model = tf.saved_model.load("/content/drive/MyDrive/QR/inference/saved_model")

# %%
print(detection_model.signatures['serving_default'].inputs)
# Out:
# [<tf.Tensor 'input_tensor:0' shape=(1, None, None, 3) dtype=uint8>, <tf.Tensor 'unknown:0' shape=() dtype=resource>, <tf.Tensor 'unknown_0:0' shape=() dtype=resource>, <tf.Tensor 'unknown_1:0' shape=() dtype=resource>, <tf.Tensor 'unknown_2:0' shape=() dtype=resource>, <tf.Tensor 'unknown_3:0' shape=() dtype=resource>, <tf.Tensor 'unknown_4:0' shape=() dtype=resource>, <tf.Tensor 'unknown_5:0' shape=() dtype=resource>, <tf.Tensor 'unknown_6:0' shape=() dtype=resource>, <tf.Tensor 'unknown_7:0' shape=() dtype=resource>, <tf.Tensor 'unknown_8:0' shape=() dtype=resource>, <tf.Tensor 'unknown_9:0' shape=() dtype=resource>, <tf.Tensor 'unknown_10:0' shape=() dtype=resource>, <tf.Tensor 'unknown_11:0' shape=() dtype=resource>, <tf.Tensor 'unknown_12:0' shape=() dtype=resource>, <tf.Tensor 'unknown_13:0' shape=() dtype=resource>, <tf.Tensor 'unknown_14:0' shape=() dtype=resource>, <tf.Tensor 'unknown_15:0' shape=() dtype=resource>, <tf.Tensor 'unknown_16:0' shape=() dtype=resource>, <tf.Ten
# ...

# %%
detection_model.signatures['serving_default'].output_shapes
# Out:
# {'detection_classes': TensorShape([1, 100]),
#  'raw_detection_scores': TensorShape([1, 12804, 2]),
#  'detection_boxes': TensorShape([1, 100, 4]),
#  'raw_detection_boxes': TensorShape([1, 12804, 4]),
#  'num_detections': TensorShape([1]),
#  'detection_anchor_indices': TensorShape([1, 100]),
#  'detection_scores': TensorShape([1, 100]),
#  'detection_multiclass_scores': TensorShape([1, 100, 2])}

# %%
import cv2
import numpy as np
filename = df.filename[0]
image = cv2.imread(filename)
image = cv2.resize(image, (320, 320))
image = np.uint8(image)
print(image.dtype)
#output_dict = run_inference_for_single_image(detection_model, image)
# Out:
# uint8

# %%
from object_detection.utils import ops as utils_ops
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as vis_util

# %%
import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile

from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image
from IPython.display import display

# %%
PATH_TO_LABELS = '/content/drive/MyDrive/QR/label_map.pbtxt'
category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS, use_display_name=True)

# %%
def run_inference_for_single_image(model, image):
  image = np.asarray(image)
  # The input needs to be a tensor, convert it using `tf.convert_to_tensor`.
  input_tensor = tf.convert_to_tensor(image)
  # The model expects a batch of images, so add an axis with `tf.newaxis`.
  input_tensor = input_tensor[tf.newaxis,...]

  # Run inference
  model_fn = model.signatures['serving_default']
  output_dict = model_fn(input_tensor)

  # All outputs are batches tensors.
  # Convert to numpy arrays, and take index [0] to remove the batch dimension.
  # We're only interested in the first num_detections.
  num_detections = int(output_dict.pop('num_detections'))
  output_dict = {key:value[0, :num_detections].numpy() 
                 for key,value in output_dict.items()}
  output_dict['num_detections'] = num_detections

  # detection_classes should be ints.
  output_dict['detection_classes'] = output_dict['detection_classes'].astype(np.int64)
   
  # Handle models with masks:
  if 'detection_masks' in output_dict:
    # Reframe the the bbox mask to the image size.
    detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
              output_dict['detection_masks'], output_dict['detection_boxes'],
               image.shape[0], image.shape[1])      
    detection_masks_reframed = tf.cast(detection_masks_reframed > 0.5,
                                       tf.uint8)
    output_dict['detection_masks_reframed'] = detection_masks_reframed.numpy()
    
  return output_dict

# %%
def show_inference(model, image_path):
  # the array based representation of the image will be used later in order to prepare the
  # result image with boxes and labels on it.
  image_np = cv2.imread(image_path)
  image_np = cv2.resize(image_np, (320, 320))
  image_np = np.uint8(image_np)

  # Actual detection.
  output_dict = run_inference_for_single_image(model, image_np)
  # Visualization of the results of a detection.
  vis_util.visualize_boxes_and_labels_on_image_array(
      image_np,
      output_dict['detection_boxes'],
      output_dict['detection_classes'],
      output_dict['detection_scores'],
      category_index,
      instance_masks=output_dict.get('detection_masks_reframed', None),
      use_normalized_coordinates=True,
      line_thickness=8, 
      min_score_thresh=.25)

  display(Image.fromarray(image_np))

# %%
images_files = df.filename
for image_path in images_files[:100]:
  show_inference(detection_model, image_path)
